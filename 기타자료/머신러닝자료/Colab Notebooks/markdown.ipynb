# %% [markdown]
# # Markdown

# %% [markdown]
# - 코드나 문자를 쓸 수 있는 줄
# - 셀(cell)
# - b키를 누르면 아래에 셀이 하나 추가됩니다

# %% [markdown]
# - 마크다운 텍스트를 HTML로 변환하기 위한 도구
# - README 파일, 블로그 등 문서를 작성하기에 용이
# - github, notion과 같은 서비스 이용자가 증가하면서 다시 주목 받기 시작
# - Jupyter Notebook 을 작성하면서 많이 사용하기 때문에 연습합니다

# %% [markdown]
# ## 목차
# - 기본 문자 입력
# - 제목
# - 목록
# - 강조
# - 링크 연결
# - 이미지
# - 코드 블록
# - 인용문
# - 수평선
# - 하이라이트
# - 체크박스
# - 표 만들기

# %% [markdown]
# ## 1. 기본 문자 입력

# %% [markdown]
# 저는 데이터 분석을 공부하고 있습니다.
#
# 지금은 마크다운에 대해 공부하고 있습니다.
# 다음 내용을 작성하고 싶습니다.<br>
# 라인 브레이크 옵션을 넣어주면 됩니다.

# %% [markdown]
# ## 2. 제목(Heading)

# %% [markdown]
# # 제목1
# ## 제목2
# ### 제목3
# #### 제목4
# ##### 제목5
# ###### 제목6

# %% [markdown]
# ## 3. 목록

# %% [markdown]
# - 순서가 없는 목록

# %% [markdown]
# - 목록 1
# - 목록 2
# - 목록 3

# %% [markdown]
# - 목록 1
#   - 목록 1-1
#     - 목록 1-2
#       - 목록 1-3

# %% [markdown]
# - 목록 1
# * 목록 2
# + 목록 3

# %% [markdown]
# - 순서가 있는 목록

# %% [markdown]
# 1. 목록 1
# 2. 목록 2
# 3. 목록 3
#   1. 목록 3의1
#   2. 목록 3의2
# 4. 목록 4

# %% [markdown]
# ## 4. 강조

# %% [markdown]
# - 이탤릭체

# %% [markdown]
# _이탤릭체_

# %% [markdown]
# *이탤릭체*

# %% [markdown]
# - 굵은 글씨 (볼드체)

# %% [markdown]
# **굵은 글씨**

# %% [markdown]
# __굵은 글씨__

# %% [markdown]
# ## 5. 링크 연결

# %% [markdown]
# [네이버](https://www.naver.com/)

# %% [markdown]
# [구글](https://www.google.co.kr/?hl=ko)

# %% [markdown]
# <https://www.naver.com>

# %% [markdown]
# <email@google.com>

# %% [markdown]
# ## 6. 이미지

# %% [markdown]
# ![이미지](data:image/jpeg;base64,...)(https://www.forbes.com/advisor/pet-insurance/pet-care/how-much-does-a-cat-cost/)

# %% [markdown]
# ## 7. 코드 블록

# %% [markdown]
# - 영문 상태
# - 키보드 상단 숫자 1키 왼쪽
# - (`) backtick
# - 코드 블록을 작성할 때 1개 또는 3개의 백틱을 사용해서 코드를 표시합니다

# %%
# 파이썬 코드
print('Hi')
# Out:
# Hi

# %% [markdown]
# print('마크다운 테스트')

# %% [markdown]
# `print('마크다운 테스트')`

# %% [markdown]
# ```python
# # 글자를 출력하는 함수
# print('hi')
# ```

# %% [markdown]
# ## 8. Blockquotes

# %% [markdown]
# > AI 서비스 개발 3개월 프로젝트
# >
# >> 프로토타입 개발 기간 1개월

# %% [markdown]
# > #### 혼합 인용문!
# >
# > - 데이터 분석 프로젝트
# > - 나만의 주제를 찾아보자!
# >
# > *재밌는* 주제면 **좋겠어요**.

# %% [markdown]
# ## 9. 수평선

# %% [markdown]
# ---

# %% [markdown]
# ***

# %% [markdown]
# ___

# %% [markdown]
# 글을 한 줄 쓴 다음에 꼭 한 칸 공백이
#
# ---
#
# 제대로 표기 되는 확인

# %% [markdown]
# ## 10. Highlight

# %% [markdown]
# 이 글 내용 중 <mark>중요한 부분</mark> 입니다.

# %% [markdown]
# ## 11. Task Lists

# %% [markdown]
# - [ ] 할 일을 했으면 체크해주세요
# - [X] 할 일을 했나요?

# %% [markdown]
# ## 12. Table

# %% [markdown]
# - 첫 번째 행은 표의 헤터를 나타냅니다
# - 두 번째 행은 각 컬럼을 구분하는 역할을 합니다
#   - 대시(-) 를 사용하여 각 컬럼의 헤더 아래에 구분을선을 만듭니다
# - 세 번째 행부터는 실제 표의 내용을 입력합니다.
# - 엔터키 하나 위에 있는키
# - 쉬프트 같이 누르기
# - | 파이프

# %% [markdown]
# | 헤더1 | 헤더2 | 헤더3|
# |---|---|---|
# |내용1|내용2|내용3|

# %% [markdown]
# |왼쪽 정렬|가운데 정렬|오른쪽 정렬|
# |:---|:---:|---:|
# |내용1|내용2|내용3|

# %% [markdown]
# ## 13. 취소선

# %% [markdown]
# ~~이 건은 취소 입니다~~

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석
#
# 데이터 분석은 **정보**를 추출하고 __의사결정__에 활용할 수 있는 <mark>인사이트를 도출</mark>하기 위한 과정입니다.
#
# ---
#
# ## 데이터 수집
#
# 데이터 수집은 분석의 첫 단계입니다.
# - 웹 스크래핑
# - 설문조사
# - 로그 파일 분석
# - API 활용
# - ~~남의 데이터 그냥 가져오기~~
#
# ---
#
# ## 데이터 전처리
#
# 데이터가 수집되면 **전처리** 단계를 거칩니다.
#
# 1. 결측치 처리
# 2. 이상치 탐지 및 제거
# 3. 데이터 정규화
# 4. 피처 엔지니어링
#
# > **Note:** 데이터 전처리는 분석의 품질을 결정하는 중요한 단계입니다.
#
# ---
#
# ## 데이터 분석 도구
#
# 데이터 분석에는 다양한 도구가 사용됩니다.
#
# - [x] **Python**: [Numpy](https://numpy.org/doc/), [Pandas](https://pandas.pydata.org/docs/)
# - [ ] **R**
# - [ ] **SQL**
# - [ ] **Excel**
#
# ---
#
# ### 프로젝트 중 사용한 주요 코드
#
# ```python
# def add_numbers(a, b):
#   """두 숫자를 더하는 함수"""
#   retrun a + b
# result = add_numbers(5, 3)
# print(result)
# ```
#
# ### 파이썬 추천 도서
# - [점프투파이썬](https://wikidocs.net/book/1)
#
# ![점프투파이썬](https://wikidocs.net/images//book/j2p_cover_4pwFNUD_Lirmdrv_U1UQjo8_e0LkdJf_RfBYr9e_HuNZjDQ_GPEKYKk_TiflQiw_bpi6gBP_c_kqquMOF.jpg)
#
# >이 책은 파이썬이란 언어를 처음 접해보는 독자들과 프로그래밍을 한 번도 해 본적이 없는 사람들을 대상으로 한다. 프로그래밍을 할 때 사용되는 전문적인 용어들을 알기 쉽게 풀어서 쓰려고 노력하였으며, 파이썬이란 언어의 개별적인 특성만을 강조하지 않고 프로그래밍 전반에 관한 사항을 파이썬이란 언어를 통해 알 수 있도록 알기 쉽게 설명하였다.
# >
# >파이썬에 대한 기본적인 지식을 알고 있는 사람이라도 이 책은 파이썬 프로그래밍에 대한 흥미를 가질 수 있는 좋은 안내서가 될 것이다. 이 책의 목표는 독자가 파이썬을 통해 프로그래밍에 대한 전반적인 이해를 갖게하는 것이며, 또 파이썬이라는 도구를 이용하여 원하는 프로그램을 쉽고 재미있게 만들 수 있게 하는 것이다.
#
# ---
#
# ## 시각화
#
# 분석결과를 이해하기 쉽게 표현하기 위해 **시각화**를 사용합니다.
#
# ![데이터시각화](https://matplotlib.org/stable/_images/sphx_glr_csd_demo_001.png)
#
# ---
#
# ## 데이터 분석 주요 내용 정리
# | 단계 | 설명 | 도구/기술|
# | ----- | -----| -------- |
# |데이터 수집|데이터를 모으는 과정|웹스크래핑, 설문조사, 로그파일, API|
# |데이터 전처리|데이터를 분석에 적합하게 가공하는 과정|결측치처리, 이상치 제거, 정규화, 피처엔지니어링|
# |데이터 분석|데이터에서 유용한 정보를 추출하는 과정|통계 분석, 머신러닝, 딥러닝|
# |시각화|분석 결과를 그래프나 차트로 표현|matplotlib, seaborn, tableau, looker|
# |결과해석|시각화된 결과를 해석하여 인사이트 도출|기업전략, 의사결정|
#
# ---
#
# ## 결론
#
# 데이터 분석은 기업의 성장과 발전에 중요한 역할을 합니다. 정확한 분석을 위해 다양한 도구와 기술을 활용해야 합니다.
#
# 데이터 분석에 대한 더 많은 정보는 [stackoverflow](https://stackoverflow.com/)에서 확인해 주세요!
